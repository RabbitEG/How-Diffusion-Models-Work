# %% [markdown]
# # Lab 1, Sampling

# %%
from typing import Dict, Tuple
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import models, transforms
from torchvision.utils import save_image, make_grid
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter
import numpy as np
from IPython.display import HTML
from diffusion_utilities import *

# %% [markdown]
# # Setting Things Up

# %%
class ContextUnet(nn.Module):
    def __init__(self, in_channels, n_feat=256, n_cfeat=10, height=28):  # cfeat - context features
        super(ContextUnet, self).__init__()

        # number of input channels, number of intermediate feature maps and number of classes
        self.in_channels = in_channels
        self.n_feat = n_feat
        self.n_cfeat = n_cfeat
        self.h = height  #assume h == w. must be divisible by 4, so 28,24,20,16...

        # Initialize the initial convolutional layer
        self.init_conv = ResidualConvBlock(in_channels, n_feat, is_res=True)

        # Initialize the down-sampling path of the U-Net with two levels
        self.down1 = UnetDown(n_feat, n_feat)        # down1 #[10, 256, 8, 8]
        self.down2 = UnetDown(n_feat, 2 * n_feat)    # down2 #[10, 256, 4,  4]
        
         # original: self.to_vec = nn.Sequential(nn.AvgPool2d(7), nn.GELU())
        self.to_vec = nn.Sequential(nn.AvgPool2d((4)), nn.GELU())

        # Embed the timestep and context labels with a one-layer fully connected neural network
        self.timeembed1 = EmbedFC(1, 2*n_feat)
        self.timeembed2 = EmbedFC(1, 1*n_feat)
        self.contextembed1 = EmbedFC(n_cfeat, 2*n_feat)
        self.contextembed2 = EmbedFC(n_cfeat, 1*n_feat)

        # Initialize the up-sampling path of the U-Net with three levels
        self.up0 = nn.Sequential(
            nn.ConvTranspose2d(2 * n_feat, 2 * n_feat, self.h//4, self.h//4), # up-sample  
            nn.GroupNorm(8, 2 * n_feat), # normalize                       
            nn.ReLU(),
        )
        self.up1 = UnetUp(4 * n_feat, n_feat)
        self.up2 = UnetUp(2 * n_feat, n_feat)

        # Initialize the final convolutional layers to map to the same number of channels as the input image
        self.out = nn.Sequential(
            nn.Conv2d(2 * n_feat, n_feat, 3, 1, 1), # reduce number of feature maps   #in_channels, out_channels, kernel_size, stride=1, padding=0
            nn.GroupNorm(8, n_feat), # normalize
            nn.ReLU(),
            nn.Conv2d(n_feat, self.in_channels, 3, 1, 1), # map to same number of channels as input
        )

    def forward(self, x, t, c=None):
        """
        x : (batch, n_feat, h, w) : input image
        t : (batch, n_cfeat)      : time step
        c : (batch, n_classes)    : context label
        """
        # x is the input image, c is the context label, t is the timestep, context_mask says which samples to block the context on

        # pass the input image through the initial convolutional layer
        x = self.init_conv(x)
        # pass the result through the down-sampling path
        down1 = self.down1(x)       #[10, 256, 8, 8]
        down2 = self.down2(down1)   #[10, 256, 4, 4]
        
        # convert the feature maps to a vector and apply an activation
        hiddenvec = self.to_vec(down2)
        
        # mask out context if context_mask == 1
        if c is None:
            c = torch.zeros(x.shape[0], self.n_cfeat).to(x)
            
        # embed context and timestep
        cemb1 = self.contextembed1(c).view(-1, self.n_feat * 2, 1, 1)     # (batch, 2*n_feat, 1,1)
        temb1 = self.timeembed1(t).view(-1, self.n_feat * 2, 1, 1)
        cemb2 = self.contextembed2(c).view(-1, self.n_feat, 1, 1)
        temb2 = self.timeembed2(t).view(-1, self.n_feat, 1, 1)
        #print(f"uunet forward: cemb1 {cemb1.shape}. temb1 {temb1.shape}, cemb2 {cemb2.shape}. temb2 {temb2.shape}")


        up1 = self.up0(hiddenvec)
        up2 = self.up1(cemb1*up1 + temb1, down2)  # add and multiply embeddings
        up3 = self.up2(cemb2*up2 + temb2, down1)
        out = self.out(torch.cat((up3, x), 1))
        return out

# %%
# hyperparameters

# diffusion hyperparameters
timesteps = 500
beta1 = 1e-4
beta2 = 0.02

# network hyperparameters
device = torch.device("cuda:0" if torch.cuda.is_available() else torch.device('cpu'))
n_feat = 64 # 64 hidden dimension feature
n_cfeat = 5 # context vector is of size 5
height = 16 # 16x16 image
save_dir = './weights/'

# %%
# construct DDPM noise schedule
b_t = (beta2 - beta1) * torch.linspace(0, 1, timesteps + 1, device=device) + beta1
a_t = 1 - b_t
ab_t = torch.cumsum(a_t.log(), dim=0).exp()    
ab_t[0] = 1

# %%
# construct model
nn_model = ContextUnet(in_channels=3, n_feat=n_feat, n_cfeat=n_cfeat, height=height).to(device)

# %% [markdown]
# # Sampling

# %%
# helper function; removes the predicted noise (but adds some noise back in to avoid collapse)
def denoise_add_noise(x, t, pred_noise, z=None):
    if z is None:
        z = torch.randn_like(x)
    noise = b_t.sqrt()[t] * z
    mean = (x - pred_noise * ((1 - a_t[t]) / (1 - ab_t[t]).sqrt())) / a_t[t].sqrt()
    return mean + noise

# %%
# load in model weights and set to eval mode
nn_model.load_state_dict(torch.load(f"{save_dir}/model_trained.pth", map_location=device))
nn_model.eval()
print("Loaded in Model")
# Out:
# Loaded in Model

# %%
# sample using standard algorithm
@torch.no_grad()
def sample_ddpm(n_sample, save_rate=20):
    # x_T ~ N(0, 1), sample initial noise
    samples = torch.randn(n_sample, 3, height, height).to(device)  

    # array to keep track of generated steps for plotting
    intermediate = [] 
    for i in range(timesteps, 0, -1):
        print(f'sampling timestep {i:3d}', end='\r')

        # reshape time tensor
        t = torch.tensor([i / timesteps])[:, None, None, None].to(device)

        # sample some random noise to inject back in. For i = 1, don't add back in noise
        z = torch.randn_like(samples) if i > 1 else 0

        eps = nn_model(samples, t)    # predict noise e_(x_t,t)
        samples = denoise_add_noise(samples, i, eps, z)
        if i % save_rate ==0 or i==timesteps or i<8:
            intermediate.append(samples.detach().cpu().numpy())

    intermediate = np.stack(intermediate)
    return samples, intermediate

# %%
# visualize samples
plt.clf()
samples, intermediate_ddpm = sample_ddpm(32)
animation_ddpm = plot_sample(intermediate_ddpm,32,4,save_dir, "ani_run", None, save=False)
HTML(animation_ddpm.to_jshtml())
# Out:
# sampling timestep 500
# sampling timestep 497
# sampling timestep 494
# sampling timestep 491
# sampling timestep 488
# sampling timestep 485
# sampling timestep 482
# sampling timestep 479
# sampling timestep 476
# sampling timestep 473
# sampling timestep 469
# sampling timestep 465
# sampling timestep 461
# sampling timestep 458
# sampling timestep 455
# sampling timestep 452
# sampling timestep 449
# sampling timestep 447
# sampling timestep 444
# sampling timestep 441
# sampling timestep 438
# sampling timestep 436
# sampling timestep 434
# sampling timestep 431
# sampling timestep 428
# sampling timestep 425
# sampling timestep 423
# sampling timestep 421
# sampling timestep 419
# sampling timestep 416
# sampling timestep 413
# sampling timestep 410
# sampling timestep 407
# sampling timestep 404
# sampling timestep 401
# sampling timestep 398
# sampling timestep 395
# sampling timestep 392
# sampling timestep 389
# sampling timestep 386
# sampling timestep 383
# sampling timestep 380
# sampling timestep 377
# sampling timestep 374
# sampling timestep 371
# sampling timestep 368
# sampling timestep 365
# sampling timestep 362
# sampling timestep 359
# sampling timestep 356
# sampling timestep 353
# sampling timestep 350
# sampling timestep 347
# sampling timestep 344
# sampling timestep 341
# sampling timestep 338
# sampling timestep 335
# sampling timestep 332
# sampling timestep 330
# sampling timestep 327
# sampling timestep 324
# sampling timestep 321
# sampling timestep 318
# sampling timestep 316
# sampling timestep 313
# sampling timestep 310
# sampling timestep 307
# sampling timestep 305
# sampling timestep 303
# sampling timestep 300
# sampling timestep 297
# sampling timestep 294
# sampling timestep 291
# sampling timestep 288
# sampling timestep 285
# sampling timestep 282
# sampling timestep 279
# sampling timestep 276
# sampling timestep 273
# sampling timestep 270
# sampling timestep 267
# sampling timestep 264
# sampling timestep 261
# sampling timestep 258
# sampling timestep 255
# sampling timestep 252
# sampling timestep 249
# sampling timestep 246
# sampling timestep 243
# sampling timestep 240
# sampling timestep 237
# sampling timestep 234
# sampling timestep 231
# sampling timestep 229
# sampling timestep 226
# sampling timestep 224
# sampling timestep 221
# sampling timestep 218
# sampling timestep 215
# sampling timestep 212
# sampling timestep 209
# sampling timestep 206
# sampling timestep 203
# sampling timestep 200
# sampling timestep 197
# sampling timestep 194
# sampling timestep 191
# sampling timestep 188
# sampling timestep 185
# sampling timestep 182
# sampling timestep 179
# sampling timestep 176
# sampling timestep 173
# sampling timestep 170
# sampling timestep 167
# sampling timestep 164
# sampling timestep 161
# sampling timestep 158
# sampling timestep 155
# sampling timestep 152
# sampling timestep 149
# sampling timestep 146
# sampling timestep 143
# sampling timestep 140
# sampling timestep 137
# sampling timestep 134
# sampling timestep 131
# sampling timestep 128
# sampling timestep 125
# sampling timestep 122
# sampling timestep 119
# sampling timestep 116
# sampling timestep 113
# sampling timestep 110
# sampling timestep 107
# sampling timestep 104
# sampling timestep 101
# sampling timestep  98
# sampling timestep  95
# sampling timestep  92
# sampling timestep  89
# sampling timestep  86
# sampling timestep  83
# sampling timestep  80
# sampling timestep  77
# sampling timestep  74
# sampling timestep  71
# sampling timestep  68
# sampling timestep  65
# sampling timestep  62
# sampling timestep  59
# sampling timestep  56
# sampling timestep  53
# sampling timestep  50
# sampling timestep  47
# sampling timestep  44
# sampling timestep  41
# sampling timestep  38
# sampling timestep  35
# sampling timestep  32
# sampling timestep  29
# sampling timestep  26
# sampling timestep  23
# sampling timestep  20
# sampling timestep  17
# sampling timestep  14
# sampling timestep  11
# sampling timestep   8
# sampling timestep   5
# sampling timestep   2
# sampling timestep   1
# gif animating frame 0 of 32
# gif animating frame 0 of 32
# gif animating frame 1 of 32
# gif animating frame 2 of 32
# gif animating frame 3 of 32
# gif animating frame 4 of 32
# gif animating frame 5 of 32
# gif animating frame 6 of 32
# gif animating frame 7 of 32
# gif animating frame 8 of 32
# gif animating frame 9 of 32
# gif animating frame 10 of 32
# gif animating frame 11 of 32
# gif animating frame 12 of 32
# gif animating frame 13 of 32
# gif animating frame 14 of 32
# gif animating frame 15 of 32
# gif animating frame 16 of 32
# gif animating frame 17 of 32
# gif animating frame 18 of 32
# gif animating frame 19 of 32
# gif animating frame 20 of 32
# gif animating frame 21 of 32
# gif animating frame 22 of 32
# gif animating frame 23 of 32
# gif animating frame 24 of 32
# gif animating frame 25 of 32
# gif animating frame 26 of 32
# gif animating frame 27 of 32
# gif animating frame 28 of 32
# gif animating frame 29 of 32
# gif animating frame 30 of 32
# gif animating frame 31 of 32
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge67abf3f23d44c9fb7fcea3fff34f70c">
#   <div class="anim-controls">
#     <input id="_anim_slidere67abf3f23d44c9fb7fcea3fff34f70c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime67abf3f23d44c9fb7fcea3fff34f70c.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anime67abf3f23d44c9fb7fcea3fff34f70c.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anime67abf3f23d44c9fb7fcea3fff34f70c.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anime67abf3f23d44c9fb7fcea3fff34f70c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anime67abf3f23d44c9fb7fcea3fff34f70c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anime67abf3f23d44c9fb7fcea3fff34f70c.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anime67abf3f23d44c9fb7fcea3fff34f70c.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anime67abf3f23d44c9fb7fcea3fff34f70c.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anime67abf3f23d44c9fb7fcea3fff34f70c.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anime67abf3f23d44c9fb7fcea3fff34f70c.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selecte67abf3f23d44c9fb7fcea3fff34f70c"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e67abf3f23d44c9fb7fcea3fff34f70c"
#              >
#       <label for="_anim_radio1_e67abf3f23d44c9fb7fcea3fff34f70c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e67abf3f23d44c9fb7fcea3fff34f70c"
#              checked>
#       <label for="_anim_radio2_e67abf3f23d44c9fb7fcea3fff34f70c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e67abf3f23d44c9fb7fcea3fff34f70c"
#              >
#       <label for="_anim_radio3_e67abf3f23d44c9fb7fcea3fff34f70c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge67abf3f23d44c9fb7fcea3fff34f70c";
#     var slider_id = "_anim_slidere67abf3f23d44c9fb7fcea3fff34f70c";
#     var loop_select_id = "_anim_loop_selecte67abf3f23d44c9fb7fcea3fff34f70c";
#     var frames = new Array(32);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjcsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvTLEjVAAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAA0A9JR

# %% [markdown]
# #### Demonstrate incorrectly sample without adding the 'extra noise'

# %%
# incorrectly sample without adding in noise
@torch.no_grad()
def sample_ddpm_incorrect(n_sample):
    # x_T ~ N(0, 1), sample initial noise
    samples = torch.randn(n_sample, 3, height, height).to(device)  

    # array to keep track of generated steps for plotting
    intermediate = [] 
    for i in range(timesteps, 0, -1):
        print(f'sampling timestep {i:3d}', end='\r')

        # reshape time tensor
        t = torch.tensor([i / timesteps])[:, None, None, None].to(device)

        # don't add back in noise
        z = 0

        eps = nn_model(samples, t)    # predict noise e_(x_t,t)
        samples = denoise_add_noise(samples, i, eps, z)
        if i%20==0 or i==timesteps or i<8:
            intermediate.append(samples.detach().cpu().numpy())

    intermediate = np.stack(intermediate)
    return samples, intermediate

# %%
# visualize samples
plt.clf()
samples, intermediate = sample_ddpm_incorrect(32)
animation = plot_sample(intermediate,32,4,save_dir, "ani_run", None, save=False)
HTML(animation.to_jshtml())
# Out:
# sampling timestep 498
# sampling timestep 495
# sampling timestep 492
# sampling timestep 489
# sampling timestep 486
# sampling timestep 483
# sampling timestep 481
# sampling timestep 478
# sampling timestep 475
# sampling timestep 472
# sampling timestep 469
# sampling timestep 466
# sampling timestep 463
# sampling timestep 460
# sampling timestep 458
# sampling timestep 456
# sampling timestep 454
# sampling timestep 451
# sampling timestep 448
# sampling timestep 445
# sampling timestep 442
# sampling timestep 439
# sampling timestep 436
# sampling timestep 433
# sampling timestep 430
# sampling timestep 427
# sampling timestep 424
# sampling timestep 421
# sampling timestep 418
# sampling timestep 415
# sampling timestep 412
# sampling timestep 410
# sampling timestep 407
# sampling timestep 404
# sampling timestep 401
# sampling timestep 399
# sampling timestep 397
# sampling timestep 395
# sampling timestep 394
# sampling timestep 392
# sampling timestep 390
# sampling timestep 389
# sampling timestep 387
# sampling timestep 384
# sampling timestep 381
# sampling timestep 379
# sampling timestep 378
# sampling timestep 376
# sampling timestep 374
# sampling timestep 372
# sampling timestep 369
# sampling timestep 366
# sampling timestep 363
# sampling timestep 361
# sampling timestep 359
# sampling timestep 356
# sampling timestep 355
# sampling timestep 352
# sampling timestep 350
# sampling timestep 347
# sampling timestep 344
# sampling timestep 341
# sampling timestep 338
# sampling timestep 336
# sampling timestep 333
# sampling timestep 331
# sampling timestep 329
# sampling timestep 326
# sampling timestep 323
# sampling timestep 320
# sampling timestep 317
# sampling timestep 314
# sampling timestep 311
# sampling timestep 308
# sampling timestep 307
# sampling timestep 304
# sampling timestep 302
# sampling timestep 300
# sampling timestep 297
# sampling timestep 295
# sampling timestep 293
# sampling timestep 290
# sampling timestep 287
# sampling timestep 284
# sampling timestep 281
# sampling timestep 280
# sampling timestep 279
# sampling timestep 278
# sampling timestep 276
# sampling timestep 274
# sampling timestep 273
# sampling timestep 270
# sampling timestep 267
# sampling timestep 264
# sampling timestep 262
# sampling timestep 259
# sampling timestep 257
# sampling timestep 256
# sampling timestep 254
# sampling timestep 253
# sampling timestep 251
# sampling timestep 249
# sampling timestep 248
# sampling timestep 247
# sampling timestep 246
# sampling timestep 245
# sampling timestep 244
# sampling timestep 243
# sampling timestep 241
# sampling timestep 239
# sampling timestep 237
# sampling timestep 235
# sampling timestep 233
# sampling timestep 230
# sampling timestep 227
# sampling timestep 224
# sampling timestep 221
# sampling timestep 218
# sampling timestep 215
# sampling timestep 212
# sampling timestep 210
# sampling timestep 208
# sampling timestep 207
# sampling timestep 205
# sampling timestep 202
# sampling timestep 199
# sampling timestep 196
# sampling timestep 193
# sampling timestep 190
# sampling timestep 187
# sampling timestep 184
# sampling timestep 182
# sampling timestep 180
# sampling timestep 177
# sampling timestep 175
# sampling timestep 173
# sampling timestep 170
# sampling timestep 167
# sampling timestep 164
# sampling timestep 161
# sampling timestep 158
# sampling timestep 155
# sampling timestep 152
# sampling timestep 149
# sampling timestep 146
# sampling timestep 143
# sampling timestep 140
# sampling timestep 137
# sampling timestep 134
# sampling timestep 131
# sampling timestep 128
# sampling timestep 125
# sampling timestep 122
# sampling timestep 119
# sampling timestep 116
# sampling timestep 113
# sampling timestep 111
# sampling timestep 109
# sampling timestep 107
# sampling timestep 104
# sampling timestep 101
# sampling timestep  98
# sampling timestep  95
# sampling timestep  92
# sampling timestep  89
# sampling timestep  87
# sampling timestep  84
# sampling timestep  81
# sampling timestep  78
# sampling timestep  75
# sampling timestep  72
# sampling timestep  69
# sampling timestep  66
# sampling timestep  63
# sampling timestep  60
# sampling timestep  57
# sampling timestep  55
# sampling timestep  52
# sampling timestep  49
# sampling timestep  46
# sampling timestep  43
# sampling timestep  40
# sampling timestep  37
# sampling timestep  34
# sampling timestep  31
# sampling timestep  28
# sampling timestep  25
# sampling timestep  22
# sampling timestep  19
# sampling timestep  16
# sampling timestep  13
# sampling timestep  10
# sampling timestep   7
# sampling timestep   4
# sampling timestep   1
# gif animating frame 0 of 32
# gif animating frame 0 of 32
# gif animating frame 1 of 32
# gif animating frame 2 of 32
# gif animating frame 3 of 32
# gif animating frame 4 of 32
# gif animating frame 5 of 32
# gif animating frame 6 of 32
# gif animating frame 7 of 32
# gif animating frame 8 of 32
# gif animating frame 9 of 32
# gif animating frame 10 of 32
# gif animating frame 11 of 32
# gif animating frame 12 of 32
# gif animating frame 13 of 32
# gif animating frame 14 of 32
# gif animating frame 15 of 32
# gif animating frame 16 of 32
# gif animating frame 17 of 32
# gif animating frame 18 of 32
# gif animating frame 19 of 32
# gif animating frame 20 of 32
# gif animating frame 21 of 32
# gif animating frame 22 of 32
# gif animating frame 23 of 32
# gif animating frame 24 of 32
# gif animating frame 25 of 32
# gif animating frame 26 of 32
# gif animating frame 27 of 32
# gif animating frame 28 of 32
# gif animating frame 29 of 32
# gif animating frame 30 of 32
# gif animating frame 31 of 32
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img86a6948e8a72425cb76e529d1e2d81d0">
#   <div class="anim-controls">
#     <input id="_anim_slider86a6948e8a72425cb76e529d1e2d81d0" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim86a6948e8a72425cb76e529d1e2d81d0.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim86a6948e8a72425cb76e529d1e2d81d0.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim86a6948e8a72425cb76e529d1e2d81d0.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim86a6948e8a72425cb76e529d1e2d81d0.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim86a6948e8a72425cb76e529d1e2d81d0.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim86a6948e8a72425cb76e529d1e2d81d0.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim86a6948e8a72425cb76e529d1e2d81d0.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim86a6948e8a72425cb76e529d1e2d81d0.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim86a6948e8a72425cb76e529d1e2d81d0.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim86a6948e8a72425cb76e529d1e2d81d0.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select86a6948e8a72425cb76e529d1e2d81d0"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_86a6948e8a72425cb76e529d1e2d81d0"
#              >
#       <label for="_anim_radio1_86a6948e8a72425cb76e529d1e2d81d0">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_86a6948e8a72425cb76e529d1e2d81d0"
#              checked>
#       <label for="_anim_radio2_86a6948e8a72425cb76e529d1e2d81d0">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_86a6948e8a72425cb76e529d1e2d81d0"
#              >
#       <label for="_anim_radio3_86a6948e8a72425cb76e529d1e2d81d0">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img86a6948e8a72425cb76e529d1e2d81d0";
#     var slider_id = "_anim_slider86a6948e8a72425cb76e529d1e2d81d0";
#     var loop_select_id = "_anim_loop_select86a6948e8a72425cb76e529d1e2d81d0";
#     var frames = new Array(32);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjcsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvTLEjVAAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAA0JRJR

# %% [markdown]
# # Acknowledgments
# Sprites by ElvGames, [FrootsnVeggies](https://zrghr.itch.io/froots-and-veggies-culinary-pixels) and  [kyrise](https://kyrise.itch.io/)
# This code is modified from, https://github.com/cloneofsimo/minDiffusion
# Diffusion model is based on [Denoising Diffusion Probabilistic Models](https://arxiv.org/abs/2006.11239) and [Denoising Diffusion Implicit Models](https://arxiv.org/abs/2010.02502)
